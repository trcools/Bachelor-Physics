# %% [markdown]
# # Mogelijke vragen
#
# - Hubble stemvorkdiagram (voordelen, nadelen, opstelling)
# - projectie en deprojectie?
# - Wat is remstraling/synchotronstraling
# - Rydberg afleiding?
# - Verschillende soorten fotonuitzendingen (spontane emissie, absorptie…)
# - Lijnprofielen
# - Voornaamste gascomponenten van het ISM (alles in detail)
# - Waarnemingen?
# - Interstellaire energie bronnen
# - Extinctie door interstellair stof
# - Oorsprong van interstellair stof
# - Hoe vormt een (proto-)ster
# - Jeans massa en straal afleiding
# - Van protoster tot hoofdreekster
# - Strömgren sfeer (eerder voor een oefening)
# - (recente) Stervorming(graad en geschiedenis uitleggen)
# - Kenicutt-Schmidt relatie?
# - Het leven van een ster met lage massa
# - Het leven van een ster met hoge massa
# - Kern-instorting supernovae
# - (single) stellar population techniek uitleggen
# - LOSVDs
# - Fundamenteel vlak
# - Dynamische modellering (en opwarming)?
# - Donkere materie (theoriën)
# - Melkweg morfologie
# - Oort vergelijkingen

# %% [markdown]
# ---
# THEORIE
#
# a) De luminositeit van sterren op de hoofdreeks stijgen langzaamaan, hoezo?
# b) Waarom leven massieve sterren(M > 8M_zon) korter dan hun lichtere counterparts(M < 8M_zon), staaf je argument met een vergelijking
# c) Hoezo kan een ster die zich op de TPAGB bevindt stofvorming veroorzaken? Bespreek ook de TPAGB.
# d) Gegeven zijn verschillende emissielijnen en geassocieerde kritische dichtheden, uit welke combinatie van 2 lijnen kan de massa bepaald worden van de geioniseerde gaswolk?
# e) Men kan spreken over de hoofdreeks van sterrenstelsels bij stervorming. Welke schaalrelatie is hier relevant en geef een beetje uitleg(gebruik mss een figuur).
#
# a) Waarom is de massadistributie in elliptische sterrenstelsels moeilijk te bepalen?
# b) Geef 2 voorbeelden van alternatieve tracers voor de massadistributie.
# c) Afleiding vd Röntgenhalo met dP/dr uit H10
#
# OEFENINGEN
#
# a) Bereken de intensiteit in de V band in lineaire eenheden (L*/pc^2) vertrekkende vanuit de logaritmische oppervlaktehelderheid.(exact zoals in wc)
# b) Gegeven is een exponentieel model voor de intensiteit en de kleurindex B - V. Bepaal de totale schijnbare magnitude in de B band.
# c) Gegeven is de temperatuur en de dichtheid van een H_2 wolk. Wat is de minimale massa voor instorting volgens het viriaaltheorema?
# d) Men beschouwt een HII gebied waarvan de dichtheid en temperatuur is gegeven. Als je weet dat een O5V ster de dominante stralingsbron is, wat is de straal van dit HII-gebied(i.e. van de Strömgrensfeer)
