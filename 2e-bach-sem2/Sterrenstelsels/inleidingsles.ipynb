# %%
import sys
from pathlib import Path
import importlib.util

# Laad lokale module expliciet vanaf bestandspad
module_path = Path("/Users/tristancools/Documents/VSC_macbook_tristan/2e-bachelor-semester-2/Sterrenstelsels/code_sterrenstelsels.py")
spec = importlib.util.spec_from_file_location("code_sterrenstelsels", module_path)
figuren = importlib.util.module_from_spec(spec)
sys.modules["code_sterrenstelsels"] = figuren
spec.loader.exec_module(figuren)

# %% [markdown]
# ---
# # Inleidingsles 10/02
# ---

# %% [markdown]
# ### **Puntenindeling**:
#
# - 40% (8/20) theorie
# - 40% (8/20) oefeningen
# - 20% (4/20) project (presentatie)

# %% [markdown]
# ### **Lessen**:
#
# Oefeningen en theorie door elkaar (wordt beetje mee gëxpeerimenteerd)
#
# Laatste kwartier van dinsdag of donderdag actualliteit. (Article)

# %% [markdown]
# ### **Presentaties**:
#
# 10min presentatie over zelf gekozen onderwerp
#
# Alleen aanwezig zijn voor de 6 mensen van je groepje.
#
# Schema opgesteld via doodle (voor wanneer je presentatie wilt geven).

# %% [markdown]
# ---
# ## **Start les**
# ___
# ### **Immanuel Kant (but he tried)**
#
# Filosoof

# %% [markdown]
# ### **Technologische vootuitgang**
# Fotographie belangrijk in de sterrenkunde:
# > - Intensiteit vergelijken met elkaar.
# > - Langere sluitingstijd (objecten zien die met het blote oog niet zichtbaar zijn).
#
# Spectroscopie:
#
# >- Roodverschuiven (objecten bewegen van de melkweg weg)
# >- Rotatiebeweging (op analoge manier) (Doppler strikes again)
#
# Sterrenkunde afhankelijk van technologie

# %% [markdown]
# ### **Toestand begin 20 $^{ste}$ eeuw**
#
# Grootte melkweg (Diameter) 50 kpc (kiloparsec)
#
# Zon ligt op 8 kpc van het centrum
#
# Kapteyn:
#
# >Misse inschatting dooor de stofverduistering waar geen rekening mee werd gehouden (werd veel verder dan 8kpc geschat door Kapteyn).
#
# Shapley:
#
# >Shapley zei dat we ons op 15 kpc van het centrum bevonden (afwijking van factor 2 is dicht bij voor sterrenkundigen).

# %%
figuren.show_parsec()

# Parsec: afstand waarbij 1 AU een parallaxhoek van 1 boogseconde heeft.
# Dit visualiseert het geometrische verband: p (in boogseconden) en d (in parsec).

# %% [markdown]
# ### Grote debat
#
# 2 hypothesen:
# - onafhankelijke stersystemen
# - ...

# %% [markdown]
# ### Begin van extragalactische sterrenkunde
#
# Periode van brightness en limunositeit gecombeerd laat ons toe de afstand te bepalen.
#
# $$F = \frac{L}{4 \pi D^2}$$
#
# Met $F$ de lichtkracht
#
#
# $$\lambda = \frac{c}{\nu}$$

# %% [markdown]
# ### Optische venster
#
# zie sterren en planeten (de cursus)
#
# 2 grote voordelen:
# -
# -

# %% [markdown]
# ### CCD detectoren
#
# CCD = charge-coupled device
#
# Zie opnieuw S&P

# %% [markdown]
# ### Telescopen

# %% [markdown]
# ### Diffractie en seeing (S&P)
#
# Maat van turbulentie
#
# We willen zo weinig mogelijke turbulentie in de atmosfeer (zo een goed mogelijke seeing)
#
# Seeing in België is een paar boogseconden (plaatsafhankelijk op aarde)

# %% [markdown]
# ### Het nabije infrarood
#
# Probleem 1:
# >...
#
# Probleem 2:
# > Transparantie van de atmosfeer
#
# Probleem 3:
# > efficientie en beschibare detectoren

# %% [markdown]
# ### Water in de atmosfeer
# ...
# paar voorbeelden
#
# ### UV straling
#
# vanuit de ruimte (Ozon: $O_3$ zal UV absorberen)

# %% [markdown]
# ### Fotometrie en imaging
#
# Fotometrie:
# >1 enkele flux
#
# Imaging:
# >Objecten ruimtelijk opgelost Foto in delen opsplitsen en de flux appart bekijken oop elk stuk.

# %% [markdown]
# ### Spectroscopie
#
# Ontbinding van licht in aparte golflengten
#
# Kan ofwel met prisma's werken --> refractie
#
# Of grating (rooster met verschillende gaatjes) --> diffractie

# %% [markdown]
# ---
# # **Week 1 les 2 Data: 12/02**
# ---

# %% [markdown]
# ### Spectroscopiie (weeral)
#
# ontbinding licht in aparte golflengten
#
# - Prisma: lage resolurie (LR)
# - Grating rooster om grism
# - combinatie
#
# We moeten vaak kijken wat het beste is in ons geval

# %% [markdown]
# ## UV-optisch-NIR conventies
#
# $$\lambda F_{\lambda} = \nu F_{\nu}$$
#
# want $\nu = \frac{c}{\lambda}$.
#
# Beide leden integreren $\int_{\lambda_1}^{\lambda_2} d\lambda F_{\lambda} = \int_{\nu_1}^{\nu_2} d\nu F_{\nu}$
