# %%
#Dezee code telt getallen op (integers)
getal_1 = 1
getal_2 = 4

som = getal_1 + getal_2

print('De som is:', som)

# %%
# Telt strings op.
deel_1 = 'hand'
deel_2 = 'doek'

som = deel_1 + deel_2
print('De woordsom is:', som)

# %%
# interaties
for i in range(5):
    print(i+1)

# %%
# While lus
i = 0
while i < 4:
    print(i)
    i= i+1
# Out:
# 0
# 1
# 2
# 3
